# %%
import pandas as pd

# %%
dt_livros = pd.read_csv("emprestimos.csv")
dt_emprestimos = pd.read_csv("livros.csv")
dt_merge = pd.merge(dt_emprestimos, dt_livros, on="id_livro", how="left")
dt_merge.loc[dt_merge["data_devolucao"].isna()]
# Out:
#     id_livro                         titulo               autor  \
# 1          1  Cracking the Coding Interview       Natalie Hayes
# 2          2  Cracking the Coding Interview       Brittany Paul
# 3          3              You Don’t Know JS       Ronald Forbes
# 7          5     Introduction to Algorithms      Carl Carson II
# 9          6         The Mythical Man-Month      Sarah Peterson
# 10         7              You Don’t Know JS        Vanessa Holt
# 11         8         The Mythical Man-Month       Kenneth Velez
# 12         8         The Mythical Man-Month       Kenneth Velez
# 13         9         The Mythical Man-Month      Maureen Taylor
# 16        11  Cracking the Coding Interview    Michael Reynolds
# 20        15                 Effective Java   Amanda Stephenson
# 25        19                  Code Complete     Andrew Williams
# 26        20                 Effective Java        Amy Robinson
# 29        22                  Code Complete       Daniel Torres
# ...
