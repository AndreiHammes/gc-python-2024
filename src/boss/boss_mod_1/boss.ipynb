# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
dt = pd.read_csv('pokedex_(update_05.20).csv')
dt.info()
dt.fillna(0, inplace=True)
dt.isnull().sum()

# analisar valores discrepantes, outliers presentes no dataframe e trata-los conforme
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 51 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1028 non-null   int64
#  1   pokedex_number    1028 non-null   int64
#  2   name              1028 non-null   object
#  3   german_name       938 non-null    object
#  4   japanese_name     938 non-null    object
#  5   generation        1028 non-null   int64
#  6   status            1028 non-null   object
#  7   species           1028 non-null   object
#  8   type_number       1028 non-null   int64
#  9   type_1            1028 non-null   object
#  10  type_2            542 non-null    object
#  11  height_m          1028 non-null   float64
#  12  weight_kg         1027 non-null   float64
#  13  abilities_number  1028 non-null   int64
#  14  ability_1         1025 non-null   object
#  15  ability_2         513 non-null    object
# ...

# %%
# Remoção de duplicatas
dt.drop_duplicates()
# Out:
#       pokedex_number                            name     status  \
# 0                  1                       Bulbasaur     Normal
# 1                  2                         Ivysaur     Normal
# 2                  3                        Venusaur     Normal
# 3                  3                   Mega Venusaur     Normal
# 4                  4                      Charmander     Normal
# ...              ...                             ...        ...
# 1023             888     Zacian Hero of Many Battles  Legendary
# 1024             889        Zamazenta Crowned Shield  Legendary
# 1025             889  Zamazenta Hero of Many Battles  Legendary
# 1026             890                       Eternatus  Legendary
# 1027             890             Eternatus Eternamax  Legendary
#
#                species    type_1  type_2  height_m  weight_kg     hp  attack  \
# 0         Seed Pokémon     Grass  Poison       0.7        6.9   45.0    49.0
# ...

# %%
# exibindo colunas existentes
dt.columns
# Out:
# Index(['Unnamed: 0', 'pokedex_number', 'name', 'german_name', 'japanese_name',
#        'generation', 'status', 'species', 'type_number', 'type_1', 'type_2',
#        'height_m', 'weight_kg', 'abilities_number', 'ability_1', 'ability_2',
#        'ability_hidden', 'total_points', 'hp', 'attack', 'defense',
#        'sp_attack', 'sp_defense', 'speed', 'catch_rate', 'base_friendship',
#        'base_experience', 'growth_rate', 'egg_type_number', 'egg_type_1',
#        'egg_type_2', 'percentage_male', 'egg_cycles', 'against_normal',
#        'against_fire', 'against_water', 'against_electric', 'against_grass',
#        'against_ice', 'against_fight', 'against_poison', 'against_ground',
#        'against_flying', 'against_psychic', 'against_bug', 'against_rock',
#        'against_ghost', 'against_dragon', 'against_dark', 'against_steel',
#        'against_fairy'],
#       dtype='object')

# %%
# Remover colunas irrelevantes
dt = df.loc[:,['pokedex_number','name', 'status', 'species', 'type_1', 'type_2', 'height_m', 'weight_kg', 'hp', 'attack', 'defense', 'speed', ]]
dt
# Out:
#       pokedex_number                            name     status  \
# 0                  1                       Bulbasaur     Normal
# 1                  2                         Ivysaur     Normal
# 2                  3                        Venusaur     Normal
# 3                  3                   Mega Venusaur     Normal
# 4                  4                      Charmander     Normal
# ...              ...                             ...        ...
# 1023             888     Zacian Hero of Many Battles  Legendary
# 1024             889        Zamazenta Crowned Shield  Legendary
# 1025             889  Zamazenta Hero of Many Battles  Legendary
# 1026             890                       Eternatus  Legendary
# 1027             890             Eternatus Eternamax  Legendary
#
#                species    type_1  type_2  height_m  weight_kg     hp  attack  \
# 0         Seed Pokémon     Grass  Poison       0.7        6.9   45.0    49.0
# ...

# %%
# ratar valores ausentes: Identifique valores nulos ou ausentes e aplique as ações necessárias para corrigi-los (preenchimento ou remoção).
dt.dropna()
# Out:
#       pokedex_number                      name     status            species  \
# 0                  1                 Bulbasaur     Normal       Seed Pokémon
# 1                  2                   Ivysaur     Normal       Seed Pokémon
# 2                  3                  Venusaur     Normal       Seed Pokémon
# 3                  3             Mega Venusaur     Normal       Seed Pokémon
# 6                  6                 Charizard     Normal      Flame Pokémon
# ...              ...                       ...        ...                ...
# 1020             886                  Drakloak     Normal  Caretaker Pokémon
# 1021             887                 Dragapult     Normal    Stealth Pokémon
# 1022             888      Zacian Crowned Sword  Legendary    Warrior Pokémon
# 1024             889  Zamazenta Crowned Shield  Legendary    Warrior Pokémon
# 1026             890                 Eternatus  Legendary   Gigantic Pokémon
#
# ...

# %%
dt.name
# Out:
# 0                            Bulbasaur
# 1                              Ivysaur
# 2                             Venusaur
# 3                        Mega Venusaur
# 4                           Charmander
#                      ...
# 1023       Zacian Hero of Many Battles
# 1024          Zamazenta Crowned Shield
# 1025    Zamazenta Hero of Many Battles
# 1026                         Eternatus
# 1027               Eternatus Eternamax
# Name: name, Length: 1028, dtype: object
