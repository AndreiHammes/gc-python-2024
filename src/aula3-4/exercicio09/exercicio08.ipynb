# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Realizei essa atividade em coop com o aluno Guilherme Cabreira, e meu código se encontra no repositório dele.

# %% [markdown]
# #### Como combinado com os professores e colega estou também fazendo essa atividade em coop com o aluno Samuel Aiedo, e a contribuição dele vai estar nessa pasta presente no meu repositório.

# %%
import pandas as pd

data = pd.read_csv('netflix.csv')
data
# Out:
#      show_id     type                                  title  \
# 0         s1    Movie                   Dick Johnson Is Dead
# 1         s2  TV Show                          Blood & Water
# 2         s3  TV Show                              Ganglands
# 3         s4  TV Show                  Jailbirds New Orleans
# 4         s5  TV Show                           Kota Factory
# ...      ...      ...                                    ...
# 8812   s5202    Movie  Joan Didion: The Center Will Not Hold
# 8813   s2914    Movie                                Fanatyk
# 8814   s3710    Movie                                  ANIMA
# 8815    s516  TV Show                            Derry Girls
# 8816   s2827  TV Show                            On My Block
#
#                   director                                               cast  \
# 0          Kirsten Johnson                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.shape
# Out:
# (8817, 12)

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2638
# cast             825
# country          832
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      show_id     type                                  title  \
# 0         s1    Movie                   Dick Johnson Is Dead
# 1         s2  TV Show                          Blood & Water
# 2         s3  TV Show                              Ganglands
# 3         s4  TV Show                  Jailbirds New Orleans
# 4         s5  TV Show                           Kota Factory
# ...      ...      ...                                    ...
# 8812   s5202    Movie  Joan Didion: The Center Will Not Hold
# 8813   s2914    Movie                                Fanatyk
# 8814   s3710    Movie                                  ANIMA
# 8815    s516  TV Show                            Derry Girls
# 8816   s2827  TV Show                            On My Block
#
#                   director                                               cast  \
# 0          Kirsten Johnson                                                NaN
# ...
