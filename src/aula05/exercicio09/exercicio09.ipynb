# %%
import pandas as pd

# %%
dt1 = pd.read_csv('desenhos.csv').drop(columns=['Unnamed: 0'])

# %%
dt2 = pd.read_csv('filmes.csv').drop(columns=['Unnamed: 0'])

# %%
dt3 = pd.read_csv('series.csv').drop(columns=['Unnamed: 0'])

# %%
dt1
# Out:
#                    desenhos  Data  Nota
# 0  Viva: a vida é uma festa  2001    10
# 1           Castelo Animado  2001     9
# 2         Viagem de Chihiro  2001     7
# 3                  Rei Leão  2001     8
# 4                Ratatuille  2001    10

# %%
dt1.sort_values(by='Nota', ascending=False).head(1)
# Out:
#                    desenhos  Data  Nota
# 0  Viva: a vida é uma festa  2001    10

# %%
dt2.sort_values(by='Nota', ascending=False).head(1)
# Out:
#           Filmes  Data  Nota
# 0  Fallen angels  1995    10

# %%
dt3.sort_values(by='Nota', ascending=False).head(1)
# Out:
#       Série  Data  Nota
# 0  Sopranos  2000    10

# %%
lista = pd.read_csv('filmes.csv').drop(columns=['Unnamed: 0'])
lista
# Out:
#                                  Filmes  Data  Nota
# 0                         Fallen angels  1995    10
# 1  O Fabuloso Destino de Amélie Poulain  2001     8
# 2                     princesa Mononoke  1997     9
# 3                  Ladrões de Bicicleta  1948    10
# 4                          Blade Runner  1982    10

# %%
lista.iloc[:3]
# Out:
#                                  Filmes  Data  Nota
# 0                         Fallen angels  1995    10
# 1  O Fabuloso Destino de Amélie Poulain  2001     8
# 2                     princesa Mononoke  1997     9

# %%
novos_filmes = {
    'Filmes': ['Little Miss Sunshine', 
               'O bom o mal e o feio',
               '2001: Uma Odisséia no espaço',
               'Amor a flor da pele',
               'Happy Togheter'],
    'Data': [2006, 1966, 1968, 2000, 1997],
    'Nota': [9, 8, 10, 10, 9]
}

# %%
dt = pd.DataFrame(novos_filmes)
dt
# Out:
#                          Filmes  Data  Nota
# 0          Little Miss Sunshine  2006     9
# 1          O bom o mal e o feio  1966     8
# 2  2001: Uma Odisséia no espaço  1968    10
# 3           Amor a flor da pele  2000    10
# 4                Happy Togheter  1997     9

# %%
dt2 = pd.concat([lista, dt])
dt2
# Out:
#                                  Filmes  Data  Nota
# 0                         Fallen angels  1995    10
# 1  O Fabuloso Destino de Amélie Poulain  2001     8
# 2                     princesa Mononoke  1997     9
# 3                  Ladrões de Bicicleta  1948    10
# 4                          Blade Runner  1982    10
# 0                  Little Miss Sunshine  2006     9
# 1                  O bom o mal e o feio  1966     8
# 2          2001: Uma Odisséia no espaço  1968    10
# 3                   Amor a flor da pele  2000    10
# 4                        Happy Togheter  1997     9

# %%
dt2.head(10).reset_index().drop(columns=['index'])
# Out:
#                                  Filmes  Data  Nota
# 0                         Fallen angels  1995    10
# 1  O Fabuloso Destino de Amélie Poulain  2001     8
# 2                     princesa Mononoke  1997     9
# 3                  Ladrões de Bicicleta  1948    10
# 4                          Blade Runner  1982    10
# 5                  Little Miss Sunshine  2006     9
# 6                  O bom o mal e o feio  1966     8
# 7          2001: Uma Odisséia no espaço  1968    10
# 8                   Amor a flor da pele  2000    10
# 9                        Happy Togheter  1997     9

# %%
media = dt2.iloc[:, 2].mean()
print(media)
# Out:
# 9.3

# %%
dt3 = dt2[dt2['Nota'] > media]
dt3
# Out:
#                          Filmes  Data  Nota
# 0                 Fallen angels  1995    10
# 3          Ladrões de Bicicleta  1948    10
# 4                  Blade Runner  1982    10
# 2  2001: Uma Odisséia no espaço  1968    10
# 3           Amor a flor da pele  2000    10

# %%
string = dt2['Filmes'].iloc[0]
string
# Out:
# 'Fallen angels'

# %%
dt2.sort_values(by='Data', ascending =False)
# Out:
#                                  Filmes  Data  Nota
# 0                  Little Miss Sunshine  2006     9
# 1  O Fabuloso Destino de Amélie Poulain  2001     8
# 3                   Amor a flor da pele  2000    10
# 4                        Happy Togheter  1997     9
# 2                     princesa Mononoke  1997     9
# 0                         Fallen angels  1995    10
# 4                          Blade Runner  1982    10
# 2          2001: Uma Odisséia no espaço  1968    10
# 1                  O bom o mal e o feio  1966     8
# 3                  Ladrões de Bicicleta  1948    10

# %%
dt2.sort_values(by='Data', ascending =True)
# Out:
#                                  Filmes  Data  Nota
# 3                  Ladrões de Bicicleta  1948    10
# 1                  O bom o mal e o feio  1966     8
# 2          2001: Uma Odisséia no espaço  1968    10
# 4                          Blade Runner  1982    10
# 0                         Fallen angels  1995    10
# 2                     princesa Mononoke  1997     9
# 4                        Happy Togheter  1997     9
# 3                   Amor a flor da pele  2000    10
# 1  O Fabuloso Destino de Amélie Poulain  2001     8
# 0                  Little Miss Sunshine  2006     9
